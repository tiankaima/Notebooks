# %%
Integrate[1/Cos[x]^2,x]
# Out:
# Tan[x]

# %%
Integrate[ArcTan[x]*x/Sqrt[1+x^2],x]
# Out:
#                         2
# -ArcSinh[x] + Sqrt[1 + x ] ArcTan[x]

# %%
Integrate[ArcTan[x],x]
# Out:
#                        2
#               Log[1 + x ]
# x ArcTan[x] - -----------
#                    2

# %%
Integrate[x/(1+Sin[x]),x]
# Out:
#           Pi + 2 x           Pi   x
# 2 Log[Sin[--------]] - x Tan[-- - -]
#              4               4    2

# %%
TrigReduce[FullSimplify[TrigReduce[D[x*(Tan[x]-Sec[x])+Log[Cos[x]]+Log[(1+Sin[x]/2)/(1-Sin[x])],x]]]]
# Out:
# (Sec[x] (25 x + 2 Cos[x] - 8 x Cos[2 x] + 6 Cos[3 x] - x Cos[4 x] - 34 x Sin[x] +
#
# >       8 Cos[x] Sin[x] - 2 x Sin[3 x] - 2 Sin[4 x])) /
#
# >   (16 Cos[x] - 10 Sin[2 x] - Sin[4 x])
