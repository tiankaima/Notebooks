# %%
VectorPlot[{1,2*x-y},{x,-5,5},{y,-5,5}]
# Out:
# -Graphics-

# %%
VectorPlot[{1,(x*y+x^2)/y^2},{x,-5,5},{y,-5,5}]
# Out:
# -Graphics-

# %%
Integrate[(7x-3)/(-7x^2+7),x]
# Out:
# -2 Log[1 - x]   5 Log[1 + x]
# ------------- - ------------
#       7              7

# %%
D[(t-1-x)^2*(t-1+x)^5,t,x]
# Out:
#                2             3                 5
# 20 (-1 + t - x)  (-1 + t + x)  - 2 (-1 + t + x)

# %%
N[Log[23/3]*5/11]
# Out:
# 0.925855

# %%
N[Exp[-5/11]*23 +2]
# Out:
# 16.5989
