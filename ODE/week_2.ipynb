# %%
DSolve[t*x'[t]+x[t]==t*x[t]^2*Log[t],x[t],t]
# Out:
#                    2
# {{x[t] -> --------------------}}
#                             2
#           t (2 C[1] - Log[t] )

# %%
Integrate[Log[t]/t,t]
# Out:
#       2
# Log[t]
# -------
#    2

# %%
DSolve[x'[t] == (t*x[t]^2 + Sin[t])/(2*x[t]),x[t],t]
# Out:
#                   2                       2
#                  t /2        I  -(1/2) + t /2      Pi       I + t
# {{x[t] -> -Sqrt[E     C[1] + - E              Sqrt[--] Erf[-------] -
#                              2                     2       Sqrt[2]
#
#                     2
#           -(1/2) + t /2      Pi       1 + I t
#          E              Sqrt[--] Erfi[-------]
#                              2        Sqrt[2]
# >        -------------------------------------]},
#                            2
#
#                     2                       2
#                    t /2        I  -(1/2) + t /2      Pi       I + t
# >   {x[t] -> Sqrt[E     C[1] + - E              Sqrt[--] Erf[-------] -
#                                2                     2       Sqrt[2]
#
#                    2
#          -(1/2) + t /2      Pi       1 + I t
#         E              Sqrt[--] Erfi[-------]
#                             2        Sqrt[2]
# >       -------------------------------------]}}
# ...

# %%
Integrate[t*Sin[t],t]
# Out:
# -(t Cos[t]) + Sin[t]

# %%
DSolve[y'[t] == t*y[t] - Sin[t], y[t],t]
# Out:
#                                   2
#                         -(1/2) + t /2      Pi           I + t          1 + I t
#             2          E              Sqrt[--] (-I Erf[-------] + Erfi[-------])
#            t /2                            2           Sqrt[2]         Sqrt[2]
# {{y[t] -> E     C[1] + ---------------------------------------------------------}}
#                                                    2

# %%
DSolve[y'[t] == t*y[t], y[t],t]
# Out:
#             2
#            t /2
# {{y[t] -> E     C[1]}}

# %%
DSolve[Exp[t]+x[t]-1-(Cos[x[t]]-t)x'[t]==0,x[t],t]
# Out:
#        t
# Solve[E  - t - Sin[x[t]] + t x[t] == C[1], x[t]]

# %%
$Assumptions = {t > 0};
FullSimplify[DSolve[x[t]^3+2*t*(t-x[t]^2)*x'[t]==0,x[t],t], Assumptions -> x \[Element] Reals]
# Out:
# Solve::ifun: Inverse functions are being used by Solve, so some solutions may not be found; use Reduce for complete solution information.
#                                         C[1]
#                                        E
# {{x[t] -> -I Sqrt[t] Sqrt[ProductLog[-(-----)]]},
#                                          t
#
#                                           C[1]
#                                          E
# >   {x[t] -> I Sqrt[t] Sqrt[ProductLog[-(-----)]]}}
#                                            t

# %%
DSolve[t*x'[t]+x[t]^2-x[t]==9t^2,x[t],t]
# Out:
#               6 t    6 C[1]
#           3 (E    - E      ) t
# {{x[t] -> --------------------}}
#               6 t    6 C[1]
#              E    + E

# %%
FullSimplify[Integrate[Sin[t]*Exp[-1/2*t^2],t]]
# Out:
# I      Pi         I + t            1 + I t
# - Sqrt[---] (Erf[-------] + I Erfi[-------])
# 2      2 E       Sqrt[2]           Sqrt[2]

# %%
DSolve[(x[t]^2-x[t])+t*x'[t]==0,x[t],t]
# Out:
#               t
# {{x[t] -> ---------}}
#            C[1]
#           E     + t

# %%
DSolve[p'[t]+p[t]/t==1/(t^2),p[t],t]
# Out:
#           C[1]   Log[t]
# {{p[t] -> ---- + ------}}
#            t       t

# %%
DSolve[x^3*t'[x]+2t[x](t[x]-x^2)==0,t[x],x]
# Out:
#                  2
#                 x
# {{t[x] -> ---------------}}
#           C[1] + 2 Log[x]

# %%
Integrate[t*Sin[t],t]
# Out:
# -(t Cos[t]) + Sin[t]

# %%
DSolve[(1+x*y[x])*y[x]+(1-x*y[x])*x*y'[x]==0,y[x],x]
# Out:
# Solve::ifun: Inverse functions are being used by Solve, so some solutions may not be found; use Reduce for complete solution information.
#                             1
# {{y[x] -> -(---------------------------------)}}
#                                          2/3
#                           -1 + (9 C[1])/2
#                          E
#             x ProductLog[-------------------]
#                                   2
#                                  x

# %%
DSolve[(x^2*y[x]^3+y[x])+(x^3*y[x]^2-x)*y'[x]==0,y[x],x]
# Out:
# Solve::ifun: Inverse functions are being used by Solve, so some solutions may not be found; use Reduce for complete solution information.
#                                   4                                         4
#                                  x                                         x
#           -I Sqrt[ProductLog[-(-------)]]            I Sqrt[ProductLog[-(-------)]]
#                                 2 C[1]                                    2 C[1]
#                                E                                         E
# {{y[x] -> -------------------------------}, {y[x] -> ------------------------------}}
#                          x                                         x
