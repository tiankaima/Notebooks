# %%
N[718/3, 2]
# Out:
#       2
# 2.4 10

# %%
Solve[2x-9==0,x]
# Out:
#        9
# {{x -> -}}
#        2

# %%
Sum[n, {n, 1, 10}]
# Out:
# 55

# %%
Plot3D[Sin[x+y], {x, -2Pi, 2Pi}, {y, -2Pi, 2Pi}]
# Out:
# -Graphics3D-

# %%
(3*x^2+2*x+5)/(x-7*x^5)
# Out:
#              2
# 5 + 2 x + 3 x
# --------------
#           5
#    x - 7 x

# %%
e^(-Integrate[P[x], x]) (Integrate[Q[x]*e^(Integrate[P[x], x]), x]+C)
# Out:
#                Integrate[P[x], x]
# C + Integrate[e                   Q[x], x]
# ------------------------------------------
#             Integrate[P[x], x]
#            e
