# %% [markdown]
# # Week 4

# %% [markdown]
# 3.1 (2)(4)(5)

# %%
(* 2 *)
Limit[x/(x-1)-1/Log[x], x->1]
(* 4 *)
Limit[(1+1/x^2)^x, x->Infinity]
(* 5 *)
Limit[Sqrt[n-Sqrt[n]]-Sqrt[n], n->Infinity]
# Out:
# 1
# -
# 2
# 1
#   1
# -(-)
#   2

# %% [markdown]
# 3.2 (5) - (8)

# %%
(* 5 *)
D[Exp[x]+Exp[Exp[x]],x]

(* 6 *)
D[x^(x^x),x]

(* 7 *)
D[(Sin[x])^Cos[x],x]

(* 8 *)
D[Log[Cos[ArcTan[(Exp[x]-Exp[-x])/2]]],x]
# Out:
#        x
#  x    E  + x
# E  + E
#   x
#  x    -1 + x    x
# x   (x       + x  Log[x] (1 + Log[x]))
#       Cos[x]
# Sin[x]       (Cos[x] Cot[x] - Log[Sin[x]] Sin[x])
#         -x    x    -x    x
#   1  (-E   + E ) (E   + E )
# -(-) ----------------------
#   4            -x    x 2
#             (-E   + E )
#         1 + ------------
#                  4

# %% [markdown]
# 3.3 (3)(4)

# %%
(* 3 *)
D[1/(1-x^2),{x,60}]
(* 4 *)
D[(1+x)/Sqrt[1-x],{x,60}]
# Out:
# (959344498183598695489193994766932218518248994260838989636409419529429539548881181736960\
#
#                        60          2 61
# >       0000000000000 x  ) / (1 - x )   +
#
# >   (14150331348208080758465611422812250223144172665347375097137038938059085708345997430\
#
#                              58          2 60
# >       6201600000000000000 x  ) / (1 - x )   +
#
# >   (99112278468593040227727354584358684825666599219572928116811548155134189304643787088\
#
#                              56          2 59
# >       1996800000000000000 x  ) / (1 - x )   +
#
# >   (43860031276331402859396587948250682365381196206362732557439593149111106761250411527\
#
#                               54          2 58
# >       53664000000000000000 x  ) / (1 - x )   +
#
# >   (13763970341322420502586955560076036505451862230549357519670188113240788108629240985\
#
#                                52          2 57
# >       944064000000000000000 x  ) / (1 - x )   +
#
# >   (32591115486774159975768398344037186439694945210193657269790481139566580414361381334\
#
#                                50          2 56
# >       574694400000000000000 x  ) / (1 - x )   +
#
# >   (60491085562573251470176193896129626346403496791647318417414150599953122738776806264\
#
#                                48          2 55
# >       930304000000000000000 x  ) / (1 - x )   +
#
# >   (90256540363204533939627971845018807564475058704997586210110002482469738689603488712\
#
#                                46          2 54
# >       753152000000000000000 x  ) / (1 - x )   +
#
# >   (11015981046688289224942800808914441725145245962225530864087718463367474002799482407\
#
#                                 44          2 53
# >       7475840000000000000000 x  ) / (1 - x )   +
#
# >   (11133673151887950434610993125248997726482267820796316450242501780283793169496058074\
#
#                                 42          2 52
# >       4970240000000000000000 x  ) / (1 - x )   +
#
# >   (93981299840936522786275147851366539632365025428486553565282294439454371754275549040\
#
#                                40          2 51
# >       607232000000000000000 x  ) / (1 - x )   +
#
# >   (66641285341754988884813286658241728102949745303835919800836536057067645425759025683\
#
#                                38          2 50
# >       339673600000000000000 x  ) / (1 - x )   +
#
# >   (39837435029977684681992976633285658891474209990303275187064698000100811848901866543\
#
#                                36          2 49
# >       697100800000000000000 x  ) / (1 - x )   +
#
# >   (20110243644940658132736839165841318190407654081643480262700929278897044442955269168\
#
#                                34          2 48
# >       693248000000000000000 x  ) / (1 - x )   +
#
# >   (85728318273645206781651723191770360978865455469620003247532076941194847511382264465\
#
#                               32          2 47
# >       32608000000000000000 x  ) / (1 - x )   +
#
# >   (30812497002701465625869025147187028293853091241254725804910079828139597366409857373\
#
#                               30          2 46
# >       04473600000000000000 x  ) / (1 - x )   +
#
# >   (93079418028994010744812680132127481304347879791290317535665866147505033711029777481\
#
#                              28          2 45
# >       0726400000000000000 x  ) / (1 - x )   +
#
# >   (23518729956523887741670583616272852896419450909831377024386161366147662261209395646\
#
#                              26          2 44
# >       9555200000000000000 x  ) / (1 - x )   +
#
# >   (49377178526293691964101677488944943096487865282268717912955442144689859398533937889\
#
#                             24          2 43
# >       280000000000000000 x  ) / (1 - x )   +
#
# >   (85389105722162023697318690394416067008963977555803046014885351077283215501224103116\
#
#                            22          2 42
# >       80000000000000000 x  ) / (1 - x )   +
#
# >   (12027367940133797240293059439701287487238218789872258310633241523690501695599248670\
#
#                            20          2 41
# >       72000000000000000 x  ) / (1 - x )   +
#
# >   (13602380408484651640807626747281217991519414107593625470359023151792829298594388377\
#
#                           18          2 40
# >       6000000000000000 x  ) / (1 - x )   +
#
# >   (12127996518054497092328478393554932125305771319707603129166261901074026122872619008\
#
#                          16          2 39
# >       000000000000000 x  ) / (1 - x )   +
#
# >   (83258557332181902235664611397402280036424059403027023770020104584032215946493952000\
#
#                        14          2 38
# >       0000000000000 x  ) / (1 - x )   +
#
# >   (42660634669079690897778601560605897991636201608532990783062103137088579116728320000\
#
#                       12          2 37
# >       000000000000 x  ) / (1 - x )   +
#
# >   (15642232711995886662518820572222162596933273923128763287122771150265812342800384000\
#
#                      10          2 36
# >       00000000000 x  ) / (1 - x )   +
#
# >   (38675850112077741747986094821428424003406446513230458676951906690217667880550400000\
#
#                    8          2 35
# >       000000000 x ) / (1 - x )   +
#
# >   (58982777948702438395621495370370145538964079649806799725198986237804722257920000000\
#
#                  6          2 34
# >       0000000 x ) / (1 - x )   + (4787563145186886233410835663179394930110720750796006\
#
#                                               4          2 33
# >       471201216415406227456000000000000000 x ) / (1 - x )   +
#
# >   (15477036029698985668353994600795457748202761047831917471555656515321856000000000000\
#
#              2          2 32
# >       000 x ) / (1 - x )   +
#
#      8320987112741390144276341183223364380754172606361245952449277696409600000000000000
# >    ----------------------------------------------------------------------------------
#                                                2 31
#                                          (1 - x )
# 8789487556892190288425309059830764945192354731509429478707969717273917181301293052480874\
#
#                                               119/2
# >     6337890625 / (144115188075855872 (1 - x)     ) +
#
# >   (69729934618011376288174118541324068565192680869974807197749893090373076304990258216\
#
#                                                                 121/2
# >       3482720947265625 (1 + x)) / (1152921504606846976 (1 - x)     )

# %% [markdown]
# 3.4 (3)-(6)

# %%
(* 3 *)
Integrate[x^2*a^x,x]
(* 4 *)
Integrate[(2x^2-5)/(x^4-5x^2+6),x]
(* 5 *)
Integrate[Log[x+Sqrt[1+x^2]],x]
(* 6 *)
Integrate[(Exp[2x]+1)/(Exp[x]+1),x]
# Out:
#  x                    2       2
# a  (2 - 2 x Log[a] + x  Log[a] )
# --------------------------------
#                   3
#             Log[a]
# (3 Sqrt[2] Log[Sqrt[2] - x] + 2 Sqrt[3] Log[Sqrt[3] - x] - 3 Sqrt[2] Log[Sqrt[2] + x] -
#
# >     2 Sqrt[3] Log[Sqrt[3] + x]) / 12
#            2                        2
# -Sqrt[1 + x ] + x Log[x + Sqrt[1 + x ]]
#  x        x               x
# E  + Log[E ] - 2 Log[1 + E ]

# %% [markdown]
# 3.5 (2N)

# %%
(* 2 *)
Integrate[Sqrt[Exp[x]-1],{x,0,Log[2]}]
(* 4 *)
Integrate[x^2/Sqrt[x^2+a^2],{x,0,a}]
(* 6 *)
Integrate[(1/2*Sqrt[4x+1]+1)/x, {x,0,1}]
(* 8 *)
Integrate[x*y^2,{x,0,1},{y,x^2,x}]
(* 10 *)
Integrate[x*y*z,{x,0,1},{y,0,x},{z,0,x+y}]
(* 12 *)
Integrate[x*Sqrt[y]*Boole[x^2<=y<=Sqrt[x]],{x,0,Infinity},{y,0,Infinity}]
# Out:
#                              1   Sqrt[1 + 4 x]
# Integrate::idiv: Integral of - + ------------- does not converge on {0, 1}.
#                              x        2 x
#     Pi
# 2 - --
#     2
#   1             2                     2                             2
# -(-) (a (a Log[a ] - 2 (Sqrt[2] Sqrt[a ] + a Log[-a + Sqrt[2] Sqrt[a ]])))
#   4
#               Sqrt[1 + 4 x]
#           1 + -------------
#                     2
# Integrate[-----------------, {x, 0, 1}]
#                   x
# 1
# --
# 40
# 17
# ---
# 144
# 6
# --
# 55

# %% [markdown]
# 3.6

# %%
y[x_] := a * Cosh[x/a]
Integrate[Sqrt[1+y'[x]^2],{x,-a,a}]
ClearAll["Global`*"]
# Out:
# 2 a Sinh[1]

# %% [markdown]
# 3.7 (3)(5)

# %%
(* 3 *)
Series[Log[(1+x)/(1-x)],{x,0,5}]
(* 5 *)
Series[Cos[x]*Cos[y],{x,0,5},{y,0,5}]
# Out:
#          3      5
#       2 x    2 x        6
# 2 x + ---- + ---- + O[x]
#        3      5
#       2    4                     2    4                      2    4
#      y    y        6       1    y    y        6   2    1    y    y         6   4       6
# (1 - -- + -- + O[y] ) + (-(-) + -- - -- + O[y] ) x  + (-- - -- + --- + O[y] ) x  + O[x]
#      2    24               2    4    48                24   48   576

# %% [markdown]
# 3.8 (6)(9)

# %%
(* 6 *)
DSolve[{y'[x]==y[x]+x,y[0]==1},y[x],x]
(* 8 *)
DSolve[{x'[t] == 2*x[t] - y[t] + z[t],y'[t] == 2*x[t] + 2*y[t] - z[t],z'[t] == x[t] + 2 * y[t] - z[t]}, {x[t], y[t], z[t]}, t]
# Out:
#                   x
# {{y[x] -> -1 + 2 E  - x}}
#            t                 t           t
# {{x[t] -> E  (1 + t) C[1] - E  t C[2] + E  t C[3],
#
#               t                     t                2          t
#              E  t (4 + 3 t) C[1]   E  (-2 - 2 t + 3 t ) C[2]   E  t (-2 + 3 t) C[3]
# >    y[t] -> ------------------- - ------------------------- + --------------------,
#                       2                        2                        2
#
#               t                     t                      t               2
#              E  t (2 + 3 t) C[1]   E  t (-4 + 3 t) C[2]   E  (2 - 4 t + 3 t ) C[3]
# >    z[t] -> ------------------- - -------------------- + ------------------------}}
#                       2                     2                        2

# %% [markdown]
# 3.9 (1)(3)

# %%
(* 1 *)
DSolve[(y+z)*D[u[x,y,z],x]+(z+x)*D[u[x,y,z],y]+(x+y)*D[u[x,y,z],z]==0,u[x,y,z],{x,y,z}]
(* 3 *)
DSolve[(x*y^3-2x^4)*D[u[x,y],x]+(3y^4-x^3*y)*D[u[x,y],y]==9*u[x,y]*(x^3-y^3),u[x,y],{x,y}]
# Out:
# Solve::ifun: Inverse functions are being used by Solve, so some solutions may not be found; use Reduce for complete solution information.
#                 (0,0,1)                     (0,1,0)
# DSolve[(x + y) u       [x, y, z] + (x + z) u       [x, y, z] +
#
#                (1,0,0)
# >     (y + z) u       [x, y, z] == 0, u[x, y, z], {x, y, z}]
#                                                  3
# {{u[x, y] -> Power[E, Inactive[Integrate][(9 K[1]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[1]   + 10 K[1]   #1 + 40 K[1]  #1  + 80 K[1]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[1]  - (80 K[1] )/x  - (x  K[1] )/y   - (10 x  K[1] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[1] )/y  - (80 K[1] )/(x  y ) - (32 y  K[1] )/x ) #1  + 32 #1  &
#
# >              , 1])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[1]  + K[1] Root[K[1]   + 10 K[1]   #1 + 40 K[1]  #1  + 80 K[1]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[1]  - (80 K[1] )/x  - (x  K[1] )/y   - (10 x  K[1] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[1] )/y  - (80 K[1] )/(x  y ) - (32 y  K[1] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 1]), {K[1], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[2]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[2]   + 10 K[2]   #1 + 40 K[2]  #1  + 80 K[2]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[2]  - (80 K[2] )/x  - (x  K[2] )/y   - (10 x  K[2] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[2] )/y  - (80 K[2] )/(x  y ) - (32 y  K[2] )/x ) #1  + 32 #1  &
#
# >              , 1])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[2]  + K[2] Root[K[2]   + 10 K[2]   #1 + 40 K[2]  #1  + 80 K[2]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[2]  - (80 K[2] )/x  - (x  K[2] )/y   - (10 x  K[2] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[2] )/y  - (80 K[2] )/(x  y ) - (32 y  K[2] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 1]), {K[2], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[3]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[3]   + 10 K[3]   #1 + 40 K[3]  #1  + 80 K[3]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[3]  - (80 K[3] )/x  - (x  K[3] )/y   - (10 x  K[3] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[3] )/y  - (80 K[3] )/(x  y ) - (32 y  K[3] )/x ) #1  + 32 #1  &
#
# >              , 1])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[3]  + K[3] Root[K[3]   + 10 K[3]   #1 + 40 K[3]  #1  + 80 K[3]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[3]  - (80 K[3] )/x  - (x  K[3] )/y   - (10 x  K[3] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[3] )/y  - (80 K[3] )/(x  y ) - (32 y  K[3] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 1]), {K[3], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[4]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[4]   + 10 K[4]   #1 + 40 K[4]  #1  + 80 K[4]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[4]  - (80 K[4] )/x  - (x  K[4] )/y   - (10 x  K[4] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[4] )/y  - (80 K[4] )/(x  y ) - (32 y  K[4] )/x ) #1  + 32 #1  &
#
# >              , 2])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[4]  + K[4] Root[K[4]   + 10 K[4]   #1 + 40 K[4]  #1  + 80 K[4]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[4]  - (80 K[4] )/x  - (x  K[4] )/y   - (10 x  K[4] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[4] )/y  - (80 K[4] )/(x  y ) - (32 y  K[4] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 2]), {K[4], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[5]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[5]   + 10 K[5]   #1 + 40 K[5]  #1  + 80 K[5]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[5]  - (80 K[5] )/x  - (x  K[5] )/y   - (10 x  K[5] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[5] )/y  - (80 K[5] )/(x  y ) - (32 y  K[5] )/x ) #1  + 32 #1  &
#
# >              , 2])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[5]  + K[5] Root[K[5]   + 10 K[5]   #1 + 40 K[5]  #1  + 80 K[5]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[5]  - (80 K[5] )/x  - (x  K[5] )/y   - (10 x  K[5] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[5] )/y  - (80 K[5] )/(x  y ) - (32 y  K[5] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 2]), {K[5], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[6]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[6]   + 10 K[6]   #1 + 40 K[6]  #1  + 80 K[6]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[6]  - (80 K[6] )/x  - (x  K[6] )/y   - (10 x  K[6] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[6] )/y  - (80 K[6] )/(x  y ) - (32 y  K[6] )/x ) #1  + 32 #1  &
#
# >              , 2])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[6]  + K[6] Root[K[6]   + 10 K[6]   #1 + 40 K[6]  #1  + 80 K[6]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[6]  - (80 K[6] )/x  - (x  K[6] )/y   - (10 x  K[6] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[6] )/y  - (80 K[6] )/(x  y ) - (32 y  K[6] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 2]), {K[6], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[7]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[7]   + 10 K[7]   #1 + 40 K[7]  #1  + 80 K[7]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[7]  - (80 K[7] )/x  - (x  K[7] )/y   - (10 x  K[7] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[7] )/y  - (80 K[7] )/(x  y ) - (32 y  K[7] )/x ) #1  + 32 #1  &
#
# >              , 3])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[7]  + K[7] Root[K[7]   + 10 K[7]   #1 + 40 K[7]  #1  + 80 K[7]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[7]  - (80 K[7] )/x  - (x  K[7] )/y   - (10 x  K[7] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[7] )/y  - (80 K[7] )/(x  y ) - (32 y  K[7] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 3]), {K[7], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[8]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[8]   + 10 K[8]   #1 + 40 K[8]  #1  + 80 K[8]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[8]  - (80 K[8] )/x  - (x  K[8] )/y   - (10 x  K[8] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[8] )/y  - (80 K[8] )/(x  y ) - (32 y  K[8] )/x ) #1  + 32 #1  &
#
# >              , 3])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[8]  + K[8] Root[K[8]   + 10 K[8]   #1 + 40 K[8]  #1  + 80 K[8]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[8]  - (80 K[8] )/x  - (x  K[8] )/y   - (10 x  K[8] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[8] )/y  - (80 K[8] )/(x  y ) - (32 y  K[8] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 3]), {K[8], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                     3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[9]  -
#
#                        15          12             9   2          6   3
# >           9 Root[K[9]   + 10 K[9]   #1 + 40 K[9]  #1  + 80 K[9]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[9]  - (80 K[9] )/x  - (x  K[9] )/y   - (10 x  K[9] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[9] )/y  - (80 K[9] )/(x  y ) - (32 y  K[9] )/x ) #1  + 32 #1  &
#
# >              , 3])/
#
#                   4                 15          12             9   2          6   3
# >         (-2 K[9]  + K[9] Root[K[9]   + 10 K[9]   #1 + 40 K[9]  #1  + 80 K[9]  #1  +
#
#                         3           9   6     6     9   12        3     9   9
# >               (80 K[9]  - (80 K[9] )/x  - (x  K[9] )/y   - (10 x  K[9] )/y  -
#
#                            9   6           9    3  3         3     9   9    4        5
# >                  (40 K[9] )/y  - (80 K[9] )/(x  y ) - (32 y  K[9] )/x ) #1  + 32 #1  &
#
#                                                   3      3 5/6
#                                                 (x  + 2 y )
# >              , 3]), {K[9], 1, x}]] C[1][Log[-(--------------)]]},
#                                                     3/2  2
#                                                    x    y
#
#                                                      3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[10]  -
#
#                         15           12              9   2           6   3
# >           9 Root[K[10]   + 10 K[10]   #1 + 40 K[10]  #1  + 80 K[10]  #1  +
#
#                          3            9   6     6      9   12        3      9   9
# >               (80 K[10]  - (80 K[10] )/x  - (x  K[10] )/y   - (10 x  K[10] )/y  -
#
#                             9   6            9    3  3         3      9   9    4        5
# >                  (40 K[10] )/y  - (80 K[10] )/(x  y ) - (32 y  K[10] )/x ) #1  + 32 #1
#
# >                & , 4])/
#
#                    4                   15           12              9   2
# >         (-2 K[10]  + K[10] Root[K[10]   + 10 K[10]   #1 + 40 K[10]  #1  +
#
#                         6   3            3            9   6     6      9   12
# >               80 K[10]  #1  + (80 K[10]  - (80 K[10] )/x  - (x  K[10] )/y   -
#
#                         3      9   9            9   6            9    3  3
# >                  (10 x  K[10] )/y  - (40 K[10] )/y  - (80 K[10] )/(x  y ) -
#
#                         3      9   9    4        5
# >                  (32 y  K[10] )/x ) #1  + 32 #1  & , 4]), {K[10], 1, x}]]
#
#                     3      3 5/6
#                   (x  + 2 y )
# >      C[1][Log[-(--------------)]]},
#                       3/2  2
#                      x    y
#
#                                                      3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[11]  -
#
#                         15           12              9   2           6   3
# >           9 Root[K[11]   + 10 K[11]   #1 + 40 K[11]  #1  + 80 K[11]  #1  +
#
#                          3            9   6     6      9   12        3      9   9
# >               (80 K[11]  - (80 K[11] )/x  - (x  K[11] )/y   - (10 x  K[11] )/y  -
#
#                             9   6            9    3  3         3      9   9    4        5
# >                  (40 K[11] )/y  - (80 K[11] )/(x  y ) - (32 y  K[11] )/x ) #1  + 32 #1
#
# >                & , 4])/
#
#                    4                   15           12              9   2
# >         (-2 K[11]  + K[11] Root[K[11]   + 10 K[11]   #1 + 40 K[11]  #1  +
#
#                         6   3            3            9   6     6      9   12
# >               80 K[11]  #1  + (80 K[11]  - (80 K[11] )/x  - (x  K[11] )/y   -
#
#                         3      9   9            9   6            9    3  3
# >                  (10 x  K[11] )/y  - (40 K[11] )/y  - (80 K[11] )/(x  y ) -
#
#                         3      9   9    4        5
# >                  (32 y  K[11] )/x ) #1  + 32 #1  & , 4]), {K[11], 1, x}]]
#
#                     3      3 5/6
#                   (x  + 2 y )
# >      C[1][Log[-(--------------)]]},
#                       3/2  2
#                      x    y
#
#                                                      3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[12]  -
#
#                         15           12              9   2           6   3
# >           9 Root[K[12]   + 10 K[12]   #1 + 40 K[12]  #1  + 80 K[12]  #1  +
#
#                          3            9   6     6      9   12        3      9   9
# >               (80 K[12]  - (80 K[12] )/x  - (x  K[12] )/y   - (10 x  K[12] )/y  -
#
#                             9   6            9    3  3         3      9   9    4        5
# >                  (40 K[12] )/y  - (80 K[12] )/(x  y ) - (32 y  K[12] )/x ) #1  + 32 #1
#
# >                & , 4])/
#
#                    4                   15           12              9   2
# >         (-2 K[12]  + K[12] Root[K[12]   + 10 K[12]   #1 + 40 K[12]  #1  +
#
#                         6   3            3            9   6     6      9   12
# >               80 K[12]  #1  + (80 K[12]  - (80 K[12] )/x  - (x  K[12] )/y   -
#
#                         3      9   9            9   6            9    3  3
# >                  (10 x  K[12] )/y  - (40 K[12] )/y  - (80 K[12] )/(x  y ) -
#
#                         3      9   9    4        5
# >                  (32 y  K[12] )/x ) #1  + 32 #1  & , 4]), {K[12], 1, x}]]
#
#                     3      3 5/6
#                   (x  + 2 y )
# >      C[1][Log[-(--------------)]]},
#                       3/2  2
#                      x    y
#
#                                                      3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[13]  -
#
#                         15           12              9   2           6   3
# >           9 Root[K[13]   + 10 K[13]   #1 + 40 K[13]  #1  + 80 K[13]  #1  +
#
#                          3            9   6     6      9   12        3      9   9
# >               (80 K[13]  - (80 K[13] )/x  - (x  K[13] )/y   - (10 x  K[13] )/y  -
#
#                             9   6            9    3  3         3      9   9    4        5
# >                  (40 K[13] )/y  - (80 K[13] )/(x  y ) - (32 y  K[13] )/x ) #1  + 32 #1
#
# >                & , 5])/
#
#                    4                   15           12              9   2
# >         (-2 K[13]  + K[13] Root[K[13]   + 10 K[13]   #1 + 40 K[13]  #1  +
#
#                         6   3            3            9   6     6      9   12
# >               80 K[13]  #1  + (80 K[13]  - (80 K[13] )/x  - (x  K[13] )/y   -
#
#                         3      9   9            9   6            9    3  3
# >                  (10 x  K[13] )/y  - (40 K[13] )/y  - (80 K[13] )/(x  y ) -
#
#                         3      9   9    4        5
# >                  (32 y  K[13] )/x ) #1  + 32 #1  & , 5]), {K[13], 1, x}]]
#
#                     3      3 5/6
#                   (x  + 2 y )
# >      C[1][Log[-(--------------)]]},
#                       3/2  2
#                      x    y
#
#                                                      3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[14]  -
#
#                         15           12              9   2           6   3
# >           9 Root[K[14]   + 10 K[14]   #1 + 40 K[14]  #1  + 80 K[14]  #1  +
#
#                          3            9   6     6      9   12        3      9   9
# >               (80 K[14]  - (80 K[14] )/x  - (x  K[14] )/y   - (10 x  K[14] )/y  -
#
#                             9   6            9    3  3         3      9   9    4        5
# >                  (40 K[14] )/y  - (80 K[14] )/(x  y ) - (32 y  K[14] )/x ) #1  + 32 #1
#
# >                & , 5])/
#
#                    4                   15           12              9   2
# >         (-2 K[14]  + K[14] Root[K[14]   + 10 K[14]   #1 + 40 K[14]  #1  +
#
#                         6   3            3            9   6     6      9   12
# >               80 K[14]  #1  + (80 K[14]  - (80 K[14] )/x  - (x  K[14] )/y   -
#
#                         3      9   9            9   6            9    3  3
# >                  (10 x  K[14] )/y  - (40 K[14] )/y  - (80 K[14] )/(x  y ) -
#
#                         3      9   9    4        5
# >                  (32 y  K[14] )/x ) #1  + 32 #1  & , 5]), {K[14], 1, x}]]
#
#                     3      3 5/6
#                   (x  + 2 y )
# >      C[1][Log[-(--------------)]]},
#                       3/2  2
#                      x    y
#
#                                                      3
# >   {u[x, y] -> Power[E, Inactive[Integrate][(9 K[15]  -
#
#                         15           12              9   2           6   3
# >           9 Root[K[15]   + 10 K[15]   #1 + 40 K[15]  #1  + 80 K[15]  #1  +
#
#                          3            9   6     6      9   12        3      9   9
# >               (80 K[15]  - (80 K[15] )/x  - (x  K[15] )/y   - (10 x  K[15] )/y  -
#
#                             9   6            9    3  3         3      9   9    4        5
# >                  (40 K[15] )/y  - (80 K[15] )/(x  y ) - (32 y  K[15] )/x ) #1  + 32 #1
#
# >                & , 5])/
#
#                    4                   15           12              9   2
# >         (-2 K[15]  + K[15] Root[K[15]   + 10 K[15]   #1 + 40 K[15]  #1  +
#
#                         6   3            3            9   6     6      9   12
# >               80 K[15]  #1  + (80 K[15]  - (80 K[15] )/x  - (x  K[15] )/y   -
#
#                         3      9   9            9   6            9    3  3
# >                  (10 x  K[15] )/y  - (40 K[15] )/y  - (80 K[15] )/(x  y ) -
#
#                         3      9   9    4        5
# >                  (32 y  K[15] )/x ) #1  + 32 #1  & , 5]), {K[15], 1, x}]]
#
#                     3      3 5/6
#                   (x  + 2 y )
# >      C[1][Log[-(--------------)]]}}
#                       3/2  2
#                      x    y
